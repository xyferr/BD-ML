# %%
import numpy as np
import pandas as pd

# %%
#reading csv file in a data frame :
cov= pd.read_csv("C:/Users/Asus/Downloads/ML/DataSets/country_wise_latest.csv")
cov.head()  #prints the first 5 rows of the data-sets
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
#Getting a discription of the data set to better get to know it
cov.describe()
# Out:
# C:\Users\Asus\AppData\Roaming\Python\Python311\site-packages\pandas\core\nanops.py:1010: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#           Confirmed         Deaths     Recovered        Active     New cases  \
# count  1.760000e+02     176.000000  1.760000e+02  1.760000e+02    176.000000
# mean   9.363777e+04    3716.096591  5.379496e+04  3.612672e+04   1299.386364
# std    3.945257e+05   14508.268847  1.956376e+05  2.197530e+05   5878.620447
# min    5.200000e+01       0.000000  0.000000e+00  0.000000e+00      0.000000
# 25%    1.476000e+03      27.750000  8.097500e+02  2.455000e+02      7.000000
# 50%    7.287500e+03     124.000000  3.880000e+03  2.080500e+03     67.500000
# 75%    4.545725e+04    1019.250000  2.534700e+04  9.896250e+03    465.500000
# max    4.290259e+06  148011.000000  1.846641e+06  2.816444e+06  56336.000000
#
#         New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
#Finding the sum of all the NULL values present in the data set
cov.isnull().sum()
# Out:
# Country/Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO Region                0
# dtype: int64

# %%
# No null values encountered , hence there is no need to handle NULL values

cov.count()  #to count the number of entries in each column
# Out:
# Country/Region            187
# Confirmed                 187
# Deaths                    187
# Recovered                 187
# Active                    187
# New cases                 187
# New deaths                187
# New recovered             187
# Deaths / 100 Cases        187
# Recovered / 100 Cases     187
# Deaths / 100 Recovered    187
# Confirmed last week       187
# 1 week change             187
# 1 week % increase         187
# WHO Region                187
# dtype: int64

# %%
cov.isna()
# Out:
#      Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0             False      False   False      False   False      False
# 1             False      False   False      False   False      False
# 2             False      False   False      False   False      False
# 3             False      False   False      False   False      False
# 4             False      False   False      False   False      False
# ..              ...        ...     ...        ...     ...        ...
# 181           False      False   False      False   False      False
# 182           False      False   False      False   False      False
# 184           False      False   False      False   False      False
# 185           False      False   False      False   False      False
# 186           False      False   False      False   False      False
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
cov[['Country/Region','Confirmed']]
# Out:
#          Country/Region  Confirmed
# 0           Afghanistan      36263
# 1               Albania       4880
# 2               Algeria      27973
# 3               Andorra        907
# 4                Angola        950
# ..                  ...        ...
# 182  West Bank and Gaza      10621
# 183      Western Sahara         10
# 184               Yemen       1691
# 185              Zambia       4552
# 186            Zimbabwe       2704
#
# [187 rows x 2 columns]

# %%
#getting a table of 10 countries with most confirmed cases
top_10_cf=cov.nlargest(10,'Confirmed')
top_10_cf
# Out:
#      Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 173              US    4290259  148011    1325804  2816444      56336
# 23           Brazil    2442375   87618    1846641   508116      23284
# 79            India    1480073   33408     951166   495499      44457
# 138          Russia     816680   13334     602249   201097       5607
# 154    South Africa     452529    7067     274925   170537       7096
# 111          Mexico     395489   44022     303810    47657       4973
# 132            Peru     389717   18418     272547    98752      13756
# 35            Chile     347923    9187     319954    18782       2133
# 177  United Kingdom     301708   45844       1437   254427        688
# 81             Iran     293606   15912     255144    22550       2434
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 173        1076          27941                3.45                  30.90
# ...

# %%
# similarly let's look at the Death toll 
cov.nlargest(10,'Deaths')
# Out:
#      Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 173              US    4290259  148011    1325804  2816444      56336
# 23           Brazil    2442375   87618    1846641   508116      23284
# 177  United Kingdom     301708   45844       1437   254427        688
# 111          Mexico     395489   44022     303810    47657       4973
# 85            Italy     246286   35112     198593    12581        168
# 79            India    1480073   33408     951166   495499      44457
# 61           France     220352   30212      81212   108928       2551
# 157           Spain     272421   28432     150376    93613          0
# 132            Peru     389717   18418     272547    98752      13756
# 81             Iran     293606   15912     255144    22550       2434
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 173        1076          27941                3.45                  30.90
# ...

# %%
cov.groupby('Country/Region').sum()
# Out:
#                     Confirmed  Deaths  Recovered  Active  New cases  \
# Country/Region
# Afghanistan             36263    1269      25198    9796        106
# Albania                  4880     144       2745    1991        117
# Algeria                 27973    1163      18837    7973        616
# Andorra                   907      52        803      52         10
# Angola                    950      41        242     667         18
# ...                       ...     ...        ...     ...        ...
# West Bank and Gaza      10621      78       3752    6791        152
# Western Sahara             10       1          8       1          0
# Yemen                    1691     483        833     375         10
# Zambia                   4552     140       2815    1597         71
# Zimbabwe                 2704      36        542    2126        192
#
#                     New deaths  New recovered  Deaths / 100 Cases  \
# Country/Region
# ...

# %%
cov.Confirmed < 50
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 182    False
# 183     True
# 184    False
# 185    False
# 186    False
# Name: Confirmed, Length: 187, dtype: bool

# %%
cov[cov.Confirmed < 50]
# Out:
#             Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 17                  Belize         48       2         26      20          0
# 49                Dominica         18       0         18       0          0
# 59                    Fiji         27       0         18       9          0
# 68               Greenland         14       0         13       1          1
# 69                 Grenada         23       0         23       0          0
# 75                Holy See         12       0         12       0          0
# 94                    Laos         20       0         19       1          0
# 140  Saint Kitts and Nevis         17       0         15       2          0
# 141            Saint Lucia         24       0         22       2          0
# 168            Timor-Leste         24       0          0      24          0
# 183         Western Sahara         10       1          8       1          0
#
# ...

# %%
# Creating new dataframe 'low_confirmed_cases' to store rows with confirmed cases less than 40
low_confirmed_cases = cov[cov['Confirmed'] < 50]

# Removing the selected rows from the 'cov' dataframe
cov = cov[cov['Confirmed'] >= 50]

# %%
cov.describe()
# Out:
# C:\Users\Asus\AppData\Roaming\Python\Python311\site-packages\pandas\core\nanops.py:1010: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#           Confirmed         Deaths     Recovered        Active     New cases  \
# count  1.760000e+02     176.000000  1.760000e+02  1.760000e+02    176.000000
# mean   9.363777e+04    3716.096591  5.379496e+04  3.612672e+04   1299.386364
# std    3.945257e+05   14508.268847  1.956376e+05  2.197530e+05   5878.620447
# min    5.200000e+01       0.000000  0.000000e+00  0.000000e+00      0.000000
# 25%    1.476000e+03      27.750000  8.097500e+02  2.455000e+02      7.000000
# 50%    7.287500e+03     124.000000  3.880000e+03  2.080500e+03     67.500000
# 75%    4.545725e+04    1019.250000  2.534700e+04  9.896250e+03    465.500000
# max    4.290259e+06  148011.000000  1.846641e+06  2.816444e+06  56336.000000
#
#         New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
# Checking for countries with no Covid fatalities & storing them in a dataframe
no_death = cov[cov.Deaths == 0 ]
no_death
# Out:
#                        Country/Region  Confirmed  Deaths  Recovered  Active  \
# 19                             Bhutan         99       0         86      13
# 30                           Cambodia        226       0        147      79
# 49                           Dominica         18       0         18       0
# 55                            Eritrea        265       0        191      74
# 59                               Fiji         27       0         18       9
# 68                          Greenland         14       0         13       1
# 69                            Grenada         23       0         23       0
# 75                           Holy See         12       0         12       0
# 94                               Laos         20       0         19       1
# 114                          Mongolia        289       0        222      67
# 130                  Papua New Guinea         62       0         11      51
# ...

# %%
#Dataframe for no Active cases 

no_act = cov[cov.Active==0]
no_act
# Out:
#     Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 24          Brunei        141       3        138       0          0
# 49        Dominica         18       0         18       0          0
# 69         Grenada         23       0         23       0          0
# 75        Holy See         12       0         12       0          0
# 143     San Marino        699      42        657       0          0
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 24            0              0                2.13                  97.87
# 49            0              0                0.00                 100.00
# 69            0              0                0.00                 100.00
# 75            0              0                0.00                 100.00
# 143           0              0                6.01                  93.99
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# ...

# %%
#Now to further analyze out data set let's use visualisation as it gives easy and intuitive view of our dDeprecationWarning

# %% [markdown]
# #DATA VISUALISATION

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,6))
plt.plot(top_10_cf['Country/Region'],top_10_cf['Confirmed'],label = 'Confirmed')

# %%
plt.figure(figsize=(10,6))
plt.plot(top_10_cf['Country/Region'],top_10_cf['Deaths'],label = 'Deaths')

# %%
plt.figure(figsize=(10, 10))

# Ploting 'Confirmed' and 'Deaths' on the same graph
plt.plot(top_10_cf['Country/Region'], top_10_cf['Confirmed'], label='Confirmed', marker='o', linestyle='-', color='blue')
plt.plot(top_10_cf['Country/Region'], top_10_cf['Deaths'], label='Deaths', marker='x', linestyle='-', color='red')

# Adding labels and title
plt.xlabel('Country/Region')
plt.ylabel('Count')


# Adding a legend
plt.legend()



#To Show the plot
plt.tight_layout() # Optional: Adjust layout for better display
plt.show()

# %%
# Extracting data for 'Confirmed' and 'Deaths' from DataFrame
Confirmed = top_10_cf['Confirmed']
Deaths = top_10_cf['Deaths']
country = top_10_cf['Country/Region']

# Calculate the x positions for the bars
xpos = np.arange(len(country))

# Create the bar chart
plt.bar(xpos-0.2, Confirmed, width=0.4, label="Confirmed Cases")
plt.bar(xpos+0.2, Deaths, width=0.4, label="Deaths")
plt.yscale('log')  # This will change the y-axis scale to a logarithmic scale, which is particularly useful when there's a large disparity between values.

# Set the x-tick labels to be the country names
plt.xticks(xpos, country, rotation=90)  # Rotating labels for readability

plt.ylabel("Count")
plt.title('COVID-19 Confirmed Cases and Deaths by Country/Region')
plt.legend()
plt.tight_layout()  # Ensuring the labels fit within the plot

plt.show()

# %% [markdown]
# PIE CHARTS

# %%
top_n_countries = 10

#To Sort the DataFrame by 'Confirmed' cases in descending order
cov_sorted = cov.sort_values(by='Confirmed', ascending=False)


top_countries_confirmed = cov_sorted.head(top_n_countries)

#getiing a list of top countries in every field
data_confirmed = top_countries_confirmed['Confirmed'].tolist()
labels_confirmed = top_countries_confirmed['Country/Region'].tolist()

# Aggregate the remaining cases into the 'Other' category
other_confirmed = cov_sorted.iloc[top_n_countries:]['Confirmed'].sum()
data_confirmed.append(other_confirmed)
labels_confirmed.append('Other')

# Define colors for the pie chart
"""colors_confirmed = ['gold', 'lightcoral', 'lightblue', 'lightgreen', 'orange', 'pink', 'purple', 'lightyellow', 'lightpink',
           'lightgray', 'lightseagreen', 'lightcoral', 'lightgreen', 'lightblue', 'khaki', 'lavender', 'lightcyan',
           'lightsteelblue', 'lightcoral', 'lightgray', 'lightsalmon']
"""
# Create a pie chart for confirmed cases with specified colors
plt.figure(figsize=(8, 8))
plt.pie(data_confirmed, labels=labels_confirmed, autopct='%1.1f%%', startangle=140)
plt.title('Confirmed Cases Distribution (Top 10 Countries)')
plt.axis('equal')
plt.show()

# Sort the DataFrame by 'Deaths' in descending order
cov_sorted = cov.sort_values(by='Deaths', ascending=False)

# Get the top 20 countries with the highest deaths
top_countries_deaths = cov_sorted.head(top_n_countries)

# Create a pie chart for the top 10 countries with deaths
data_deaths = top_countries_deaths['Deaths'].tolist()
labels_deaths = top_countries_deaths['Country/Region'].tolist()

#To Aggregate the remaining deaths into the 'Other' category
other_deaths = cov_sorted.iloc[top_n_countries:]['Deaths'].sum()
data_deaths.append(other_deaths)
labels_deaths.append('Other')

# Define colors for the pie chart
colors_deaths = ['gold', 'lightcoral', 'lightblue', 'lightgreen', 'orange', 'pink', 'purple', 'lightyellow', 'lightpink',
           'lightgray', 'lightseagreen', 'lightcoral', 'lightgreen', 'lightblue', 'khaki', 'lavender', 'lightcyan',
           'lightsteelblue', 'lightcoral', 'lightgray', 'lightsalmon']

# Creating a pie chart for deaths with specified colors
plt.figure(figsize=(8, 8))
plt.pie(data_deaths, labels=labels_deaths, autopct='%1.1f%%', startangle=140, colors=colors_deaths)
plt.title('Deaths Distribution (Top 10 Countries)')
plt.axis('equal')
plt.show()

# Sort the DataFrame by 'Recovered' cases in descending order
cov_sorted = cov.sort_values(by='Recovered', ascending=False)

# Getting the top 10 countries with the highest recoveries
top_countries_recovered = cov_sorted.head(top_n_countries)

# Creating a pie chart for the top 20 countries with recoveries
data_recovered = top_countries_recovered['Recovered'].tolist()
labels_recovered = top_countries_recovered['Country/Region'].tolist()


other_recovered = cov_sorted.iloc[top_n_countries:]['Recovered'].sum()
data_recovered.append(other_recovered)
labels_recovered.append('Other')

# Define colors for the pie chart
colors_recovered = ['gold', 'lightcoral', 'lightblue', 'lightgreen', 'orange', 'pink', 'purple', 'lightyellow', 'lightpink',
           'lightgray', 'lightseagreen', 'lightcoral', 'lightgreen', 'lightblue', 'khaki', 'lavender', 'lightcyan',
           'lightsteelblue', 'lightcoral', 'lightgray', 'lightsalmon']

# Create a pie chart for recoveries with specified colors
plt.figure(figsize=(8, 8))
plt.pie(data_recovered, labels=labels_recovered, autopct='%1.1f%%', startangle=140, colors=colors_recovered)
plt.title('Recovered Cases Distribution (Top 10 Countries)')
plt.axis('equal')
plt.show()

# %%
# Group data by 'WHO Region' and calculate the sum of confirmed cases in each continent
continent_counts = cov.groupby('WHO Region')['Confirmed'].sum()

# Create a pie chart
plt.figure(figsize=(6, 6))
plt.pie(continent_counts, labels=continent_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Confirmed Cases by WHO region')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

# Show the pie chart
plt.show()

# %%
# Using Histograph Distribution Chart to gain an insigt on data distribution

# %%
plt.figure(figsize=(12, 6))
plt.subplot(2, 2, 1)
plt.hist(cov['Confirmed'], bins=20, edgecolor='k')
plt.title('Confirmed Cases Distribution')

plt.subplot(2, 2, 2)
plt.hist(cov['Deaths'], bins=20, edgecolor='k')
plt.title('Deaths Distribution')

plt.subplot(2, 2, 3)
plt.hist(cov['Recovered'], bins=20, edgecolor='k')
plt.title('Recovered Cases Distribution')

plt.subplot(2, 2, 4)
plt.hist(cov['Active'], bins=20, edgecolor='k')
plt.title('Active Cases Distribution')

plt.tight_layout()
plt.show()

# %%
#Seaborn charts are more smooth and intuitive 

plt.figure(figsize=(12, 6))

# Creating KDE plots for 'Confirmed,' 'Deaths,' 'Recovered,' and 'Active' columns
plt.subplot(2, 2, 1)
sns.kdeplot(cov['Confirmed'], color='blue', fill=True)
plt.title('Confirmed Cases Distribution')

plt.subplot(2, 2, 2)
sns.kdeplot(cov['Deaths'], color='red', fill=True)
plt.title('Deaths Distribution')

plt.subplot(2, 2, 3)
sns.kdeplot(cov['Recovered'], color='green', fill=True)
plt.title('Recovered Cases Distribution')

plt.subplot(2, 2, 4)
sns.kdeplot(cov['Active'], color='purple', fill=True)
plt.title('Active Cases Distribution')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=cov.nlargest(10, 'Confirmed'), x='Country/Region', y='Confirmed')
plt.xticks(rotation=45)
plt.title('Top 10 Countries with the Highest Confirmed Cases')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=cov[['Confirmed', 'Deaths', 'Recovered']])
plt.title('Box Plot of COVID-19 Cases')
plt.xticks(rotation=45)
plt.show()

# %%
numeric_columns = cov.select_dtypes(include=[np.number])  # Select only numeric columns
corr_matrix = numeric_columns.corr()  # Calculate the correlation matrix

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
# Set the threshold for correlations to be displayed
threshold = 0.5  # You can adjust this threshold as needed

# Create a mask for correlations above the threshold
mask = np.abs(corr_matrix) >= threshold

# Set up the matplotlib figure
plt.figure(figsize=(10, 8))

# Create a heatmap with the masked correlation matrix
sns.heatmap(corr_matrix[mask], annot=True, cmap='coolwarm', linewidths=0.5)

# Set the title for the heatmap
plt.title(f'Correlation Heatmap (Threshold: {threshold})')

# Display the heatmap
plt.show()
